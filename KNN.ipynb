# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification
from matplotlib import colors
import plotly.graph_objects as go
import folium
from folium import plugins
from sklearn.model_selection import train_test_split
import mglearn
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
         'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
dataFrame = pd.read_csv('testdata.csv', sep=',', nrows=1_400_000, names=names)
dataFrame.fillna('0', inplace=True)

#print(dataFrame.shape)
#print(dataset.head())
print(dataFrame.City.unique())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 19
#      15 from sklearn.preprocessing import StandardScaler
#      17 names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
#      18          'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
# ---> 19 dataFrame = pd.read_csv('testdata.csv', sep=',', nrows=1_400_000, names=names)
#      20 dataFrame.fillna('0', inplace=True)
#      22 #print(dataFrame.shape)
#      23 #print(dataset.head())
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification
from matplotlib import colors
import plotly.graph_objects as go
import folium
from folium import plugins
from sklearn.model_selection import train_test_split
import mglearn
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
         'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
dataset = pd.read_csv('testdata.csv', sep=',', nrows=1_400_00, names=names)
dataset.fillna('0', inplace=True)
# Make Mbps into X
x = dataset.iloc[:, [6]]

# Make City into Y
y = dataset.iloc[:,2]

popCenter = np.array(dataset.iloc[:, [0,1,2]])

print (popCenter)

print (x)
print ("\n")
print (y)

x_train, x_test, y_train, y_test = train_test_split(x, popCenter, test_size=0.3)

scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

classifier = KNeighborsClassifier(n_neighbors=10)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

print(classification_report(y_test, y_pred))

ZeroDivisionError = confusion_matrix(y_test, y_pred)
print(ZeroDivisionError)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 19
#      15 from sklearn.preprocessing import StandardScaler
#      17 names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
#      18          'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
# ---> 19 dataset = pd.read_csv('testdata.csv', sep=',', nrows=1_400_00, names=names)
#      20 dataset.fillna('0', inplace=True)
#      21 # Make Mbps into X
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification
from matplotlib import colors
import plotly.graph_objects as go
import folium
from folium import plugins
from sklearn.model_selection import train_test_split
import mglearn
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import *
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
         'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
dataset = pd.read_csv('testdata.csv', sep=',', nrows=1_400_000, names=names)


#dataset.fillna('0', inplace=True)

#dataset.where(dataset['City'] !='Tiller', '1' )

dataset.head()


# Use Mpbs to predict if Lat and Long are in city
# Mpbs, Lat, Long
x = dataset.iloc[:, [6,13,14]]
# City
y = dataset.iloc[:,2]
y = y.to_frame()
y = y.notnull().astype('int')
y = y.values.ravel()

print (x)
print ("\n")
print (y.shape)



x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

classifier = KNeighborsClassifier(n_neighbors=10)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

print(classification_report(y_test, y_pred))

ZeroDivisionError = confusion_matrix(y_test, y_pred)
print(ZeroDivisionError)
# Out:
#                Mbps  MinRTT  LossRate
# 0         68.159229  15.857  0.000000
# 1         76.744481  16.194  0.000000
# 2          8.088556  23.036  0.000000
# 3         27.124351  21.898  0.000000
# 4          8.266963  20.000  0.000000
# ...             ...     ...       ...
# 1048570   14.129729  18.606  0.000021
# 1048571  234.351104  15.897  0.000000
# 1048572  164.885260  15.636  0.000000
# 1048573   41.368126  18.912  0.000042
# 1048574   29.927483  14.150  0.000000
#
# [1048575 rows x 3 columns]
#
#
# (1048575,)
#               precision    recall  f1-score   support
#
#            0       0.33      0.00      0.00      4048
#            1       0.99      1.00      0.99    310525
#
#     accuracy                           0.99    314573
#    macro avg       0.66      0.50      0.50    314573
# weighted avg       0.98      0.99      0.98    314573
#
# [[     1   4047]
#  [     2 310523]]

# %% [markdown]
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
#
# scaler = StandardScaler()
# scaler.fit(x_train)
#
# x_train = scaler.transform(x_train)
# x_test = scaler.transform(x_test)
#
# classifier = KNeighborsClassifier(n_neighbors=10)
# classifier.fit(x_train, y_train)
#
# y_pred = classifier.predict(x_test)
#
# print(classification_report(y_test, y_pred))
#
# ZeroDivisionError = confusion_matrix(y_test, y_pred)
# print(ZeroDivisionError)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification
from matplotlib import colors
import plotly.graph_objects as go
import folium
from folium import plugins
from sklearn.model_selection import train_test_split
import mglearn
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import *
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
         'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
dataframe = pd.read_csv('testdata.csv', sep=',', nrows=1_400_000, names=names)

# Replace all NaN values with "No City"
dataframe.fillna("No City", inplace=True)

# create a new dataframe with only the columns we want
newDataframe = dataframe[['City', 'Mbps', 'MinRTT', 'LossRate']]
# Convert to numpy to get around error
newDataframe.to_numpy()

X = newDataframe.drop(columns=['City'])
y = newDataframe['City']
#y = y.to_frame()
#y = y.notnull().astype('int')
#y = y.values.ravel()

# Split the data into training and testing. 70% training, 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

#print(X)
#print("\n")
#print(y)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Input Mbps, MinRTT, LossRate to predict city
#prediction = model.predict([[300, 10, 0.0000001], [10, 40, 0.00001], [100, 20, 0.000001], [0.1, 30, 0.0001],[0,25,0.0001]])
#prediction
predictionScore = model.predict(X_test)
score = accuracy_score(y_test, predictionScore)
score
# Out:
# C:\Users\01sti\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.10848992125834067

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification
from matplotlib import colors
import plotly.graph_objects as go
import folium
from folium import plugins
from sklearn.model_selection import train_test_split
import mglearn
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import *
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression , LinearRegression, TweedieRegressor, SGDRegressor, Lasso
from sklearn.pipeline import Pipeline, make_pipeline

names = ['Lat', 'Long', 'City', 'PostalCode', 'Accuracy',	'CountryCode', 'Mbps',	'StartTime',
         'Endtime', 'UUID', 'TestTime',	'CongestionControl', 'MeanThroughputMbps',	'MinRTT', 'LossRate']
dataFrame = pd.read_csv('testdata.csv', sep=',', nrows=1_400_000, names=names)

# New dataset with only the columns we want
newDataFrame = dataFrame[['MinRTT', 'Mbps']]
newDataFrame = newDataFrame[newDataFrame['MinRTT'] < 4000 ]
newDataFrame = newDataFrame[newDataFrame['Mbps'] <2000]

# Convert to numpy to get around error

X = newDataFrame.drop(columns=['MinRTT'])
y = newDataFrame['MinRTT']

# Split the data into training and testing. 70% training, 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Dataframe to numpy
newDataFrame = newDataFrame.to_numpy()

#print(X)
#print("\n")
#print(y)
print (X_test)
print("\n")
print (y_test)

model = Lasso()

model.fit(X_train, y_train)
model.score(X_test, y_test)
model.set_params(alpha=0.1, max_iter=1, tol=10)
pred_X = model.predict(X_test)
plt.scatter(X_test, y_test, alpha=0.3 ,color='blue')
plt.plot(X_test, y_test, color='red', linewidth=1)
#plt.show()
# Out:
#               Mbps
# 297251   89.157130
# 121923   27.697946
# 240335   36.906723
# 240668  246.877220
# 254317   26.884081
# ...            ...
# 742313    5.397644
# 734373    0.429605
# 403716  393.510911
# 682505   55.922710
# 568744    0.692594
#
# [314463 rows x 1 columns]
#
#
# 297251    22.000
# 121923    18.889
# 240335    18.526
# 240668    15.293
# 254317    13.663
#            ...
# 742313    16.915
# 734373    22.447
# 403716    13.073
# 682505    15.494
# 568744     2.922
# Name: MinRTT, Length: 314463, dtype: float64
